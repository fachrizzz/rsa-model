# %% [markdown]
# # RSA-Lite: Review Sentiment Analysis Classifier Lite
# **Model Spesifications**
# ```
# version: v1.0.0 Lite
# total_param: 77,954
# model_type: Custom Recurrent Neural Network (RNN)
# model_layers: [
#     Embedding,
#     LSTM,
#     Dense,
#     Dense,
#     Dropout,
#     Dense
# ]
# train_data_length: 1,280,000
# test_data_length: 320,000
# ```
#
# **WARNING:**
# 1. **THIS MODEL IS STILL UNDER DEVELOPMENT AND MIGHT BE UNSTABLE!**
#
# Data source: [Kaggle](https://www.kaggle.com/datasets/kritanjalijain/amazon-reviews)
#
# Kaggle public API (require 'kaggle.json' file, visit [Kaggle API](https://www.kaggle.com/docs/api)):
# ```
# # command prompt
# kaggle datasets download -d kritanjalijain/amazon-reviews
# ```

# %% [markdown]
# ## Importing Dependencies

# %%
try:
    import numpy as np
    import pandas as pd
    import os
    import shutil
    from zipfile import ZipFile
    from IPython.display import display
    from sklearn.model_selection import train_test_split

    import tensorflow as tf
    import keras
    from keras.preprocessing.text import Tokenizer
    from keras.preprocessing.sequence import pad_sequences
    from keras import Sequential
    from keras.layers import Embedding, LSTM, Dense, Dropout

    import matplotlib.pyplot as plt
    from sklearn.metrics import classification_report
    import json
except Exception:
    raise Exception(f"Error on importing dependencies!")

# for google colab users
from google.colab import files

# %%
def kaggle(origin_path: str, dataset_urls=None, copy=True):
    root_dir = "/root/.kaggle"
    file_name = "kaggle.json"
    file_loc = os.path.join(root_dir, file_name)

    if not os.path.isdir(root_dir):
        os.mkdir(root_dir)

    if copy:
        shutil.copy(origin_path, root_dir)
    else:
        shutil.move(origin_path, root_dir)

    os.chmod(file_loc, 600)
    print(f"'kaggle.json' file has been copied to {file_loc}!")

    if dataset_urls is not None:
        from kaggle.api.kaggle_api_extended import KaggleApi

        api = KaggleApi()
        api.authenticate()

        for dataset in dataset_urls:
            api.dataset_download_cli(dataset)

        print(f"Dataset has been successfully downloaded!")

def unzip(path: str, del_src: bool):
    zip_ref = ZipFile(path, 'r')
    zip_ref.extractall(os.getcwd())
    zip_ref.close()

    if del_src:
        os.remove(path)

    print(f"\"{path}\" has been extracted!")

def ws_setup(ws_name: str, data_origins: list):
    loc = os.getcwd()
    ws_path = os.path.join(loc, ws_name)

    if not os.path.isdir(ws_path):
        os.mkdir(ws_path)
    else:
        raise Exception(f"\"{ws_name}\" directory already exists!")

    for data in data_origins:
        shutil.move(data, ws_path)

    os.chdir(ws_path)

    print(f"current workspace directory \"{os.getcwd()}\"")

def display_dfs(dataframes: list):
    for dataframe in dataframes:
        display(dataframe)

# %% [markdown]
# ## Project Setup

# %%
files.upload()

kaggle(origin_path="./kaggle.json", dataset_urls=['kritanjalijain/amazon-reviews'], copy=False)
# Out:
#      <input type="file" id="files-e9b797b9-2155-4bcd-9d2f-552dd5e3e89a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9b797b9-2155-4bcd-9d2f-552dd5e3e89a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# 'kaggle.json' file has been copied to /root/.kaggle/kaggle.json!
# Downloading amazon-reviews.zip to /content
# 100%|██████████| 1.29G/1.29G [00:05<00:00, 255MB/s]
# Dataset has been successfully downloaded!

# %%
unzip("./amazon-reviews.zip", del_src=True)
# Out:
# "./amazon-reviews.zip" has been extracted!

# %%
ws_setup(ws_name="workspace", data_origins=['./train.csv', './test.csv'])
# Out:
# current workspace directory "/content/workspace"

# %%
headers = ['class', 'title', 'review']
train = pd.read_csv("./train.csv", names=headers)
test = pd.read_csv("./test.csv", names=headers)

df = pd.concat([train, test], axis=0)

display_dfs([df])
# Out:
#         class                                              title  \
# 0           2                     Stuning even for the non-gamer
# 1           2              The best soundtrack ever to anything.
# 2           2                                           Amazing!
# 3           2                               Excellent Soundtrack
# 4           2  Remember, Pull Your Jaw Off The Floor After He...
# ...       ...                                                ...
# 399995      1                         Unbelievable- In a Bad Way
# 399996      1                    Almost Great, Until it Broke...
# 399997      1                                   Disappointed !!!
# 399998      2                            Classic Jessica Mitford
# 399999      1                        Comedy Scene, and Not Heard
#
#                                                    review
# 0       This sound track was beautiful! It paints the ...
# 1       I'm reading a lot of reviews saying that this ...
# 2       This soundtrack is my favorite music of all ti...
# 3       I truly like this soundtrack and I enjoy video...
# 4       If you've played the game, you know how divine...
# ...                                                   ...
# 399995  We bought this Thomas for our son who is a hug...
# 399996  My son recieved this as a birthday gift 2 mont...
# 399997  I bought this toy for my son who loves the "Th...
# 399998  This is a compilation of a wide range of Mitfo...
# 399999  This DVD will be a disappointment if you get i...
#
# [4000000 rows x 3 columns]

# %%
df['class'].replace(to_replace=[1, 2], value=['negative', 'positive'], inplace=True)
dummy = pd.get_dummies(df['class'])

df.drop(labels=['class'], axis=1, inplace=True)
df = pd.concat([df, dummy], axis=1)

display_dfs([df])
# Out:
#                                                     title  \
# 0                          Stuning even for the non-gamer
# 1                   The best soundtrack ever to anything.
# 2                                                Amazing!
# 3                                    Excellent Soundtrack
# 4       Remember, Pull Your Jaw Off The Floor After He...
# ...                                                   ...
# 399995                         Unbelievable- In a Bad Way
# 399996                    Almost Great, Until it Broke...
# 399997                                   Disappointed !!!
# 399998                            Classic Jessica Mitford
# 399999                        Comedy Scene, and Not Heard
#
#                                                    review  negative  positive
# 0       This sound track was beautiful! It paints the ...         0         1
# 1       I'm reading a lot of reviews saying that this ...         0         1
# 2       This soundtrack is my favorite music of all ti...         0         1
# 3       I truly like this soundtrack and I enjoy video...         0         1
# 4       If you've played the game, you know how divine...         0         1
# ...                                                   ...       ...       ...
# 399995  We bought this Thomas for our son who is a hug...         1         0
# 399996  My son recieved this as a birthday gift 2 mont...         1         0
# 399997  I bought this toy for my son who loves the "Th...         1         0
# 399998  This is a compilation of a wide range of Mitfo...         0         1
# 399999  This DVD will be a disappointment if you get i...         1         0
#
# [4000000 rows x 4 columns]

# %%
df_lite = df.copy()
df_lite.drop(df_lite.index[2000000:4000000], inplace=True)
display_dfs([df_lite, df])
# Out:
#                                    title  \
# 400000        Not So Simple Sand Castles
# 400001                      Great cooler
# 400002                        Great size
# 400003                      Cooler great
# 400004                buy something else
# ...                                  ...
# 1999995  Missed to many important scenes
# 1999996              terrible adaptation
# 1999997                 Love Jane Austen
# 1999998                      A nice film
# 1999999                       Persuasion
#
#                                                     review  negative  positive
# 400000   I found this book beyond what I wanted to get ...         1         0
# 400001   This is one nice cooler - large but not too la...         0         1
# 400002   The size is great for almost everything you co...         0         1
# 400003   My son was happy with his Christmas gift. He p...         0         1
# 400004   I will be searching for a different cooler, as...         1         0
# ...                                                    ...       ...       ...
# 1999995  I read this book prior to watching any adaptat...         1         0
# 1999996  I don't expect Jane Austen movie adaptations t...         1         0
# 1999997  This is my favorite movie version of Jane Aust...         0         1
# 1999998  I was not familiar with this story at all befo...         0         1
# 1999999  This was a disappointment, the lead role Anne ...         1         0
#
# [1600000 rows x 4 columns]
#                                                     title  \
# 0                          Stuning even for the non-gamer
# 1                   The best soundtrack ever to anything.
# 2                                                Amazing!
# 3                                    Excellent Soundtrack
# 4       Remember, Pull Your Jaw Off The Floor After He...
# ...                                                   ...
# 399995                         Unbelievable- In a Bad Way
# 399996                    Almost Great, Until it Broke...
# 399997                                   Disappointed !!!
# 399998                            Classic Jessica Mitford
# 399999                        Comedy Scene, and Not Heard
#
#                                                    review  negative  positive
# 0       This sound track was beautiful! It paints the ...         0         1
# 1       I'm reading a lot of reviews saying that this ...         0         1
# 2       This soundtrack is my favorite music of all ti...         0         1
# 3       I truly like this soundtrack and I enjoy video...         0         1
# 4       If you've played the game, you know how divine...         0         1
# ...                                                   ...       ...       ...
# 399995  We bought this Thomas for our son who is a hug...         1         0
# 399996  My son recieved this as a birthday gift 2 mont...         1         0
# 399997  I bought this toy for my son who loves the "Th...         1         0
# 399998  This is a compilation of a wide range of Mitfo...         0         1
# 399999  This DVD will be a disappointment if you get i...         1         0
#
# [4000000 rows x 4 columns]

# %%
train, test = train_test_split(df_lite, test_size=0.2, random_state=16, shuffle=True)
display_dfs([train, test])
# Out:
#                                                     title  \
# 685954                                Not what I expected
# 1237038                         Awesome for dog clipping.
# 1913299                                       Notice.....
# 893540           Thunder Wagon from the Wind River Series
# 1134243                              Why all the fuss????
# ...                                                   ...
# 1223748                                      Easy Install
# 498939                            the miracle in a bottle
# 498885   What on Earth Am I Here For? Purpose Driven Life
# 1319673                                  DANTE IS THE MAN
# 1029417                               Works as advertised
#
#                                                     review  negative  positive
# 685954   I went into reading this book immediately afte...         1         0
# 1237038  These clippers come with an adjustable blade. ...         0         1
# 1913299  notice that the reviews from 2007 are all good...         1         0
# 893540   I have been reading the Wind River series, and...         0         1
# 1134243  If you will allow a voice of dissent here, I a...         1         0
# ...                                                    ...       ...       ...
# 1223748  Installation was very easy and the winch worke...         0         1
# 498939   my skin was a wreck, dry, kind of scaly and th...         0         1
# 498885   It's great like all Warren's writing. Is very ...         0         1
# 1319673  This is by far 1 of the best books I've ever r...         0         1
# 1029417  This feeder is very nice. The ring can be full...         0         1
#
# [1280000 rows x 4 columns]
#                                                      title  \
# 1297867                             Un-American Expedition
# 1896803                                         Very handy
# 1774745                                      Dissapointing
# 1452126  Must remind myself not to spend time with book...
# 1794199                                        Great fit!!
# ...                                                    ...
# 1931515              Dont waste your time with 'new' Lamb.
# 1620305                                  It's OK, I guess.
# 800650                                 call the bomb squad
# 506168                                      Not so durable
# 922801                  Pretty good album but not her best
#
#                                                     review  negative  positive
# 1297867  I purchased this and an American Expedition co...         1         0
# 1896803  I am very glad I have this book. For some, the...         0         1
# 1774745  After the brilliant "Go Now", "Godlike" clocks...         1         0
# 1452126  Crappy mystery novel about a forensic anthropo...         1         0
# 1794199  These mats slipped right in, and fit snug to k...         0         1
# ...                                                    ...       ...       ...
# 1931515  Lamb 1 and 2 - good.Lamb 3 and Songs for the F...         1         0
# 1620305  I mulled over buying this funnel/strainer for ...         1         0
# 800650   Somehow the spirit of Christmas and gangsta ra...         1         0
# 506168   I have bought a couple Kong items for my three...         1         0
# 922801   OK this album rocks the songs in it are just a...         0         1
#
# [320000 rows x 4 columns]

# %% [markdown]
# ## Preprocessing

# %%
voc_sz = 1500
embedding_dim = 16

y = ['negative', 'positive']

train_text, train_label = train['review'].values, train[y].values
test_text, test_label = test['review'].values, test[y].values

tokenizer = Tokenizer(num_words=voc_sz, oov_token='x')
tokenizer.fit_on_texts(train_text)
tokenizer.fit_on_texts(test_text)

# %%
train_seq = tokenizer.texts_to_sequences(train_text)
test_seq = tokenizer.texts_to_sequences(test_text)

# %%
samples = train_text[:1001]
print(type(samples))

length = list()

for sample in samples:
    txt_length = len(sample)
    length.append(txt_length)

avg_len = round(sum(length) / len(length))
max_len = round(avg_len / 4)
print(f'average text length: {avg_len}\npadding maxlen (sigma i=0 to n=301 train_i / 4): {max_len}')
# Out:
# <class 'numpy.ndarray'>
# average text length: 410
# padding maxlen (sigma i=0 to n=301 train_i / 4): 102

# %%
padded_train_txt = pad_sequences(train_seq, padding='post', maxlen=max_len)
padded_test_txt = pad_sequences(test_seq, padding='post', maxlen=max_len)

# %% [markdown]
# ## Modeling

# %%
model = Sequential()

model.add(Embedding(input_dim=voc_sz, output_dim=embedding_dim))
model.add(LSTM(64))
model.add(Dense(128, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.6))
model.add(Dense(2, activation="sigmoid"))

model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, None, 16)          24000
#
#  lstm (LSTM)                 (None, 64)                20736
#
#  dense (Dense)               (None, 128)               8320
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 77,954
# Trainable params: 77,954
# Non-trainable params: 0
# _________________________________________________________________

# %%
class callback(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy')>0.925):
            print("\naccuracy reached >92%)")
            self.model.stop_training = True

alpha_callback = callback()

# %% [markdown]
# ## Training

# %%
hist = model.fit(
    padded_train_txt,
    train_label,
    callbacks=[alpha_callback],
    validation_data=(padded_test_txt, test_label),
    epochs=30
)
# Out:
# Epoch 1/30
# 40000/40000 [==============================] - 312s 8ms/step - loss: 0.3040 - accuracy: 0.8749 - val_loss: 0.2597 - val_accuracy: 0.8968
# Epoch 2/30
# 40000/40000 [==============================] - 302s 8ms/step - loss: 0.2479 - accuracy: 0.9013 - val_loss: 0.2305 - val_accuracy: 0.9061
# Epoch 3/30
# 40000/40000 [==============================] - 293s 7ms/step - loss: 0.2290 - accuracy: 0.9098 - val_loss: 0.2222 - val_accuracy: 0.9096
# Epoch 4/30
# 40000/40000 [==============================] - 293s 7ms/step - loss: 0.2181 - accuracy: 0.9148 - val_loss: 0.2199 - val_accuracy: 0.9123
# Epoch 5/30
# 40000/40000 [==============================] - 300s 7ms/step - loss: 0.2107 - accuracy: 0.9179 - val_loss: 0.2138 - val_accuracy: 0.9146
# Epoch 6/30
# 40000/40000 [==============================] - 311s 8ms/step - loss: 0.2057 - accuracy: 0.9204 - val_loss: 0.2107 - val_accuracy: 0.9161
# Epoch 7/30
# 40000/40000 [==============================] - 300s 8ms/step - loss: 0.2019 - accuracy: 0.9219 - val_loss: 0.2120 - val_accuracy: 0.9169
# Epoch 8/30
# 40000/40000 [==============================] - 309s 8ms/step - loss: 0.1987 - accuracy: 0.9233 - val_loss: 0.2122 - val_accuracy: 0.9146
# Epoch 9/30
# 40000/40000 [==============================] - 298s 7ms/step - loss: 0.1963 - accuracy: 0.9243 - val_loss: 0.2078 - val_accuracy: 0.9174
# Epoch 10/30
# 39997/40000 [============================>.] - ETA: 0s - loss: 0.1944 - accuracy: 0.9253
# accuracy reached >92%)
# 40000/40000 [==============================] - 322s 8ms/step - loss: 0.1944 - accuracy: 0.9253 - val_loss: 0.2148 - val_accuracy: 0.9177

# %%
model.save("rsa_v1-lite.h5")

# %%
export_dir = 'rsa_v1-lite/'
tf.saved_model.save(model, export_dir)

shutil.make_archive("rsa_v1-lite", "zip", "./rsa_v1-lite")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: rsa_v1-lite/assets
# INFO:tensorflow:Assets written to: rsa_v1-lite/assets
# '/content/workspace/rsa_v1-lite.zip'

# %%
with open('token.txt', 'w') as f:
    f.write(json.dumps(tokenizer.word_index))

with open("token.py", "w") as f:
    f.write(json.dumps(tokenizer.word_index))

with open("token_index_w.txt", "w") as f:
    f.write(json.dumps(tokenizer.index_word))

with open("token_index_w.py", "w") as f:
    f.write(json.dumps(tokenizer.index_word))

# %% [markdown]
# ## Testing

# %%
def rsa_predict(review: str, display_array=True):
    seq = tokenizer.texts_to_sequences(review)
    padded_txt = pad_sequences(seq, padding="post", maxlen=max_len)

    raw_pred = model.predict(padded_txt)

    if raw_pred[-1][0] > raw_pred[-1][1]:
        txt_class = "Negative"
    elif raw_pred[-1][1] > raw_pred[-1][0]:
        txt_class = "Positive"
    else:
        raise Exception(f"RSA-Lite was unable to classify the given text. Received array:\n{raw_pred}")

    print(f"Original Text: \n{review}")

    if display_array:
        print(f"Class: {txt_class}\n{raw_pred}")
    else:
        print(f"Class: {txt_class}")

# %% [markdown]
# ## Evaluation

# %%
reviews = train['review'].tolist()

rsa_predict(reviews[-1], display_array=False)
# Out:
# Original Text:
# This feeder is very nice. The ring can be full of birds yet the feeding holes remain open. So far the squirrels haven't been able to get in.
# Class: Positive
